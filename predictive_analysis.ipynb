# %% [markdown]
# # Task 3: Predictive Analysis

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV, learning_curve, validation_curve
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#       3 import seaborn as sns
#       4 import matplotlib.pyplot as plt
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\__init__.py:138
#     120 from pandas.core.reshape.api import (
#     121     concat,
#     122     lreshape,
#    (...)
#     134     qcut,
#     135 )
#     137 from pandas import api, arrays, errors, io, plotting, tseries
# --> 138 from pandas import testing  # noqa:PDF015
#     139 from pandas.util._print_versions import show_versions
#     141 from pandas.io.api import (
#     142     # excel
#     143     ExcelFile,
#    (...)
#     171     read_spss,
#     172 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\testing.py:6
#       1 """
#       2 Public testing utility functions.
#       3 """
# ----> 6 from pandas._testing import (
#       7     assert_extension_array_equal,
#       8     assert_frame_equal,
#       9     assert_index_equal,
#      10     assert_series_equal,
#      11 )
#      13 __all__ = [
#      14     "assert_extension_array_equal",
#      15     "assert_frame_equal",
#      16     "assert_series_equal",
#      17     "assert_index_equal",
#      18 ]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_testing\__init__.py:69
#      60 from pandas._testing._random import (
#      61     randbool,
#      62     rands,
#      63     rands_array,
#      64 )
#      65 from pandas._testing._warnings import (
#      66     assert_produces_warning,
#      67     maybe_produces_warning,
#      68 )
# ---> 69 from pandas._testing.asserters import (
#      70     assert_almost_equal,
#      71     assert_attr_equal,
#      72     assert_categorical_equal,
#      73     assert_class_equal,
#      74     assert_contains_all,
#      75     assert_copy,
#      76     assert_datetime_array_equal,
#      77     assert_dict_equal,
#      78     assert_equal,
#      79     assert_extension_array_equal,
#      80     assert_frame_equal,
#      81     assert_index_equal,
#      82     assert_indexing_slices_equivalent,
#      83     assert_interval_array_equal,
#      84     assert_is_sorted,
#      85     assert_is_valid_plot_return_object,
#      86     assert_metadata_equivalent,
#      87     assert_numpy_array_equal,
#      88     assert_period_array_equal,
#      89     assert_series_equal,
#      90     assert_sp_array_equal,
#      91     assert_timedelta_array_equal,
#      92     raise_assert_detail,
#      93 )
#      94 from pandas._testing.compat import (
#      95     get_dtype,
#      96     get_obj,
#      97 )
#      98 from pandas._testing.contexts import (
#      99     RNGContext,
#     100     decompress_file,
#    (...)
#     106     with_csv_dialect,
#     107 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pandas\_testing\asserters.py:17
#      15 from pandas._libs.missing import is_matching_na
#      16 from pandas._libs.sparse import SparseIndex
# ---> 17 import pandas._libs.testing as _testing
#      18 from pandas.util._exceptions import find_stack_level
#      20 from pandas.core.dtypes.common import (
#      21     is_bool,
#      22     is_categorical_dtype,
#    (...)
#      27     needs_i8_conversion,
#      28 )
#
# File <frozen importlib._bootstrap>:404, in parent(self)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Loading the Customer Profile model

# %%
df_customer_profile = pd.read_csv('dataset/customer_profile_kmeans.csv', sep='\t', index_col=0) # e.g., customer_profile_fcmeans or customer_profile_birch
df_customer_profile
# Out:
#                    I        Iu      Imax         E      Savg         F  \
# CustomerID
# 12347.0     3.330211  1.939519  2.829947  4.239118  2.777935  0.778151
# 12348.0     3.035029  0.954243  2.778151  2.550341  2.417438  0.477121
# 12349.0     2.799341  1.857332  2.799341  3.903268  3.163623  0.000000
# 12350.0     2.292256  1.204120  2.292256  2.500000  2.468938  0.000000
# 12352.0     2.665581  1.755875  2.096910  3.158366  2.324080  0.778151
# ...              ...       ...       ...       ...       ...       ...
# 18280.0     1.653213  1.000000  1.653213  1.846439  2.256718  0.000000
# 18281.0     1.732394  0.845098  1.732394  1.842371  1.907519  0.000000
# 18282.0     1.991226  1.079181  1.845098  3.022055  1.945961  0.301030
# 18283.0     3.131939  2.418301  2.382017  2.627193  2.105421  1.204120
# 18287.0     3.200303  1.770852  2.995635  4.198218  2.787054  0.477121
#
#                    M cluster
# CustomerID
# 12347.0     3.556087    high
# 12348.0     2.894560  medium
# 12349.0     3.163623    high
# 12350.0     2.468938  medium
# 12352.0     3.102231  medium
# ...              ...     ...
# 18280.0     2.256718     low
# 18281.0     1.907519     low
# 18282.0     2.246991     low
# 18283.0     3.309541    high
# 18287.0     3.264175    high
#
# [4205 rows x 8 columns]

# %%
customer_profile = df_customer_profile.to_numpy()

# %%
def plot_learning_curve(pipeline, X, y, scorer='accuracy', cv=5, train_sizes=np.linspace(.1, 1.0, 5), 
                        shuffle=False, random_state=None):

    train_sizes, train_scores, test_scores = learning_curve(pipeline, X, y, train_sizes=train_sizes, cv=cv,
                                                            scoring=scorer, n_jobs=-1, shuffle=shuffle,
                                                            random_state=random_state)

    mean_train_score = np.mean(train_scores, axis=1)
    std_train_score = np.std(train_scores, axis=1)
    mean_test_score = np.mean(test_scores, axis=1)
    std_test_score = np.std(test_scores, axis=1)

    plt.title(str(pipeline['estimator'].__class__.__name__) + ' learning curve')
    plt.xlabel('training set size')
    plt.ylabel('score')

    plt.plot(train_sizes, mean_train_score, label='train score', color='navy', marker='.', lw=2)
    plt.fill_between(train_sizes, mean_train_score + std_train_score,
                     mean_train_score - std_train_score, color='navy', alpha=0.2)
    plt.plot(train_sizes, mean_test_score, label='cross-validation score', color='darkorange', marker='.', lw=2)
    plt.fill_between(train_sizes, mean_test_score + std_test_score,
                     mean_test_score - std_test_score, color='darkorange', alpha=0.2)

    plt.legend(loc='lower right').get_frame().set_facecolor('white')


def plot_validation_curve(pipeline, X, y, param_grid, param_name, scorer='accuracy', cv=5):
    
    param_range = param_grid[param_name]
    train_scores, test_scores = validation_curve(pipeline, X, y, param_name=param_name, param_range=param_range,
                                                 cv=cv, scoring=scorer, n_jobs=-1)

    mean_train_score = np.mean(train_scores, axis=1)
    std_train_score = np.std(train_scores, axis=1)
    mean_test_score = np.mean(test_scores, axis=1)
    std_test_score = np.std(test_scores, axis=1)

    plt.title(str(pipeline['estimator'].__class__.__name__) + ' validation curve')
    plt.xlabel(param_name)
    plt.ylabel('score')

    plt.plot(param_range, mean_train_score, label='training score', color='navy', marker='.', lw=2)
    plt.fill_between(param_range, mean_train_score - std_train_score,
                     mean_train_score + std_train_score, alpha=0.2, color='navy')
    plt.plot(param_range, mean_test_score, label='cross-validation score', color='darkorange', marker='.', lw=2)
    plt.fill_between(param_range, mean_test_score - std_test_score,
                     mean_test_score + std_test_score, alpha=0.2, color='darkorange')

    plt.legend(loc='lower right').get_frame().set_facecolor('white')


def print_pretty_cv_results(grid):
    df = pd.DataFrame(grid.cv_results_)[['params', 'mean_train_score', 'mean_test_score', 'rank_test_score']].sort_values(by='rank_test_score')
    df['params'] = df['params'].apply(lambda param_dict: {k.replace('estimator__', ''): v for k, v in param_dict.items()})
    df.rename(columns={'mean_test_score': 'mean_val_score', 
                       'rank_test_score': 'rank_val_score'}, inplace=True)
    
    def highlight_equal(s, value, column):
        is_max = pd.Series(data=False, index=s.index)
        is_max[column] = s.loc[column] == value
        return ['background-color: lightyellow' if is_max.any() else '' for v in is_max]

    return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()

# %% [markdown]
# ## Splitting train and test set

# %%
X, y = customer_profile[:, :-1], customer_profile[:, -1]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, stratify=y)

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC

# %%
pipeline = Pipeline([('scaler', StandardScaler()), 
                     ('estimator', SVC())])

tuned_parameters = {'estimator__C': (1, 10, 100, 1000)}

svc_grid = GridSearchCV(pipeline,
                        param_grid=tuned_parameters,
                        scoring='accuracy',
                        cv=5,  # 5 fold cross validation
                        n_jobs=-1,  # use all processors
                        refit=True,  # refit the best model on the full development set
                        return_train_score=True,
                        verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 4 candidates, totalling 20 fits

# %%
print_pretty_cv_results(svc_grid)
# Out:
# C:\Users\akila\AppData\Local\Temp\ipykernel_13376\3005877394.py:63: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()
# <style type="text/css">
# #T_44cd6_row0_col0, #T_44cd6_row0_col1, #T_44cd6_row0_col2, #T_44cd6_row0_col3 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_44cd6">
#   <thead>
#     <tr>
#       <th id="T_44cd6_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_44cd6_level0_col1" class="col_heading level0 col1" >mean_train_score</th>
#       <th id="T_44cd6_level0_col2" class="col_heading level0 col2" >mean_val_score</th>
#       <th id="T_44cd6_level0_col3" class="col_heading level0 col3" >rank_val_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_44cd6_row0_col0" class="data row0 col0" >{'C': 10}</td>
#       <td id="T_44cd6_row0_col1" class="data row0 col1" >0.995243</td>
#       <td id="T_44cd6_row0_col2" class="data row0 col2" >0.990485</td>
#       <td id="T_44cd6_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_44cd6_row1_col0" class="data row1 col0" >{'C': 100}</td>
#       <td id="T_44cd6_row1_col1" class="data row1 col1" >0.997939</td>
#       <td id="T_44cd6_row1_col2" class="data row1 col2" >0.989851</td>
#       <td id="T_44cd6_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <td id="T_44cd6_row2_col0" class="data row2 col0" >{'C': 1000}</td>
#       <td id="T_44cd6_row2_col1" class="data row2 col1" >0.999921</td>
#       <td id="T_44cd6_row2_col2" class="data row2 col2" >0.988584</td>
#       <td id="T_44cd6_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_44cd6_row3_col0" class="data row3 col0" >{'C': 1}</td>
#       <td id="T_44cd6_row3_col1" class="data row3 col1" >0.991516</td>
#       <td id="T_44cd6_row3_col2" class="data row3 col2" >0.984776</td>
#       <td id="T_44cd6_row3_col3" class="data row3 col3" >4</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_learning_curve(svc_grid.best_estimator_, X, y)

plt.savefig('tex/img/classification/svm_lc.png')

# %%
plot_validation_curve(svc_grid.best_estimator_, X, y, param_grid=tuned_parameters, param_name='estimator__C')

plt.savefig('tex/img/classification/svm_vc.png')

# %% [markdown]
# ### Evaluation on the test set

# %%
y_pred = svc_grid.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9933460076045627

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.99      1.00      0.99       312
#          low       1.00      1.00      1.00       232
#       medium       1.00      0.99      0.99       508
#
#     accuracy                           0.99      1052
#    macro avg       0.99      0.99      0.99      1052
# weighted avg       0.99      0.99      0.99      1052

# %%
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['high', 'medium', 'low']), 
                         columns=['high', 'medium', 'low'], index=['high', 'medium', 'low'])
sns.heatmap(confusion, annot=True, fmt='g', cmap='YlGnBu');

plt.savefig('tex/img/classification/svm_confusion.png')

# %% [markdown]
# ## Neural Network

# %%
from sklearn.neural_network import MLPClassifier

# %%
pipeline = Pipeline([('scaler', StandardScaler()), 
                     ('estimator', MLPClassifier())])

tuned_parameters = {'estimator__hidden_layer_sizes': ((50,), (100,), (150,)), 
                    'estimator__activation': ('logistic', 'tanh'), 
                    'estimator__solver': ('lbfgs',)}

mlp_grid = GridSearchCV(pipeline,
                        param_grid=tuned_parameters,
                        scoring='accuracy',
                        cv=5,  # 5 fold cross validation
                        n_jobs=-1,  # use all processors
                        refit=True,  # refit the best model on the full development set
                        return_train_score=True,
                        verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits

# %%
print_pretty_cv_results(mlp_grid)
# Out:
# C:\Users\akila\AppData\Local\Temp\ipykernel_13376\3005877394.py:63: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()
# <style type="text/css">
# #T_4f33d_row0_col0, #T_4f33d_row0_col1, #T_4f33d_row0_col2, #T_4f33d_row0_col3 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_4f33d">
#   <thead>
#     <tr>
#       <th id="T_4f33d_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_4f33d_level0_col1" class="col_heading level0 col1" >mean_train_score</th>
#       <th id="T_4f33d_level0_col2" class="col_heading level0 col2" >mean_val_score</th>
#       <th id="T_4f33d_level0_col3" class="col_heading level0 col3" >rank_val_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f33d_row0_col0" class="data row0 col0" >{'activation': 'tanh', 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'}</td>
#       <td id="T_4f33d_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_4f33d_row0_col2" class="data row0 col2" >0.997464</td>
#       <td id="T_4f33d_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_4f33d_row1_col0" class="data row1 col0" >{'activation': 'logistic', 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'}</td>
#       <td id="T_4f33d_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_4f33d_row1_col2" class="data row1 col2" >0.996195</td>
#       <td id="T_4f33d_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <td id="T_4f33d_row2_col0" class="data row2 col0" >{'activation': 'tanh', 'hidden_layer_sizes': (50,), 'solver': 'lbfgs'}</td>
#       <td id="T_4f33d_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_4f33d_row2_col2" class="data row2 col2" >0.994927</td>
#       <td id="T_4f33d_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_4f33d_row3_col0" class="data row3 col0" >{'activation': 'logistic', 'hidden_layer_sizes': (150,), 'solver': 'lbfgs'}</td>
#       <td id="T_4f33d_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_4f33d_row3_col2" class="data row3 col2" >0.994925</td>
#       <td id="T_4f33d_row3_col3" class="data row3 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_4f33d_row4_col0" class="data row4 col0" >{'activation': 'logistic', 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'}</td>
#       <td id="T_4f33d_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_4f33d_row4_col2" class="data row4 col2" >0.994608</td>
#       <td id="T_4f33d_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_4f33d_row5_col0" class="data row5 col0" >{'activation': 'tanh', 'hidden_layer_sizes': (100,), 'solver': 'lbfgs'}</td>
#       <td id="T_4f33d_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_4f33d_row5_col2" class="data row5 col2" >0.994607</td>
#       <td id="T_4f33d_row5_col3" class="data row5 col3" >6</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_learning_curve(mlp_grid.best_estimator_, X, y)

plt.savefig('tex/img/classification/nn_lc.png')

# %% [markdown]
# ### Evaluation on the test set

# %%
y_pred = mlp_grid.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9990494296577946

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       1.00      1.00      1.00       312
#          low       1.00      1.00      1.00       232
#       medium       1.00      1.00      1.00       508
#
#     accuracy                           1.00      1052
#    macro avg       1.00      1.00      1.00      1052
# weighted avg       1.00      1.00      1.00      1052

# %%
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['high', 'medium', 'low']), 
                         columns=['high', 'medium', 'low'], index=['high', 'medium', 'low'])
sns.heatmap(confusion, annot=True, fmt='g', cmap='YlGnBu');

plt.savefig('tex/img/classification/nn_confusion.png')

# %% [markdown]
# ## Naive Bayes

# %%
from sklearn.naive_bayes import GaussianNB

# %%
pipeline = Pipeline([('scaler', StandardScaler()), 
                     ('estimator', GaussianNB())])

gnb_grid = GridSearchCV(pipeline, 
                        param_grid={}, 
                        scoring='accuracy', 
                        cv=5,  # 5 fold cross validation 
                        n_jobs=-1,  # use all processors 
                        refit=True,  # refit the best model on the full development set 
                        return_train_score=True, 
                        verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits

# %%
print_pretty_cv_results(gnb_grid)
# Out:
# C:\Users\akila\AppData\Local\Temp\ipykernel_13376\3005877394.py:63: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()
# <style type="text/css">
# #T_fc8c3_row0_col0, #T_fc8c3_row0_col1, #T_fc8c3_row0_col2, #T_fc8c3_row0_col3 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_fc8c3">
#   <thead>
#     <tr>
#       <th id="T_fc8c3_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_fc8c3_level0_col1" class="col_heading level0 col1" >mean_train_score</th>
#       <th id="T_fc8c3_level0_col2" class="col_heading level0 col2" >mean_val_score</th>
#       <th id="T_fc8c3_level0_col3" class="col_heading level0 col3" >rank_val_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_fc8c3_row0_col0" class="data row0 col0" >{}</td>
#       <td id="T_fc8c3_row0_col1" class="data row0 col1" >0.975737</td>
#       <td id="T_fc8c3_row0_col2" class="data row0 col2" >0.974308</td>
#       <td id="T_fc8c3_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_learning_curve(gnb_grid.best_estimator_, X, y)

plt.savefig('tex/img/classification/nb_lc.png')

# %% [markdown]
# ### Evaluation on the test set

# %%
y_pred = gnb_grid.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9610266159695817

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.97      0.98      0.97       312
#          low       0.94      0.95      0.95       232
#       medium       0.97      0.95      0.96       508
#
#     accuracy                           0.96      1052
#    macro avg       0.96      0.96      0.96      1052
# weighted avg       0.96      0.96      0.96      1052

# %%
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['high', 'medium', 'low']), 
                         columns=['high', 'medium', 'low'], index=['high', 'medium', 'low'])
sns.heatmap(confusion, annot=True, fmt='g', cmap='YlGnBu');

plt.savefig('tex/img/classification/nb_confusion.png')

# %% [markdown]
# ## K-Nearest Neighbors

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
pipeline = Pipeline([('scaler', StandardScaler()), 
                     ('estimator', KNeighborsClassifier())])

tuned_parameters = {'estimator__n_neighbors': (30, 50, 55, 60, 65, 70, 75, 80, 85, 100),
                    'estimator__weights': ('uniform', 'distance')}

knn_grid = GridSearchCV(pipeline,
                        param_grid=tuned_parameters,
                        scoring='accuracy',
                        cv=5,  # 5 fold cross validation
                        n_jobs=-1,  # use all processors
                        refit=True,  # refit the best model on the full development set
                        return_train_score=True,
                        verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits

# %%
print_pretty_cv_results(knn_grid)
# Out:
# C:\Users\akila\AppData\Local\Temp\ipykernel_13376\3005877394.py:63: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()
# <style type="text/css">
# #T_3ef0f_row0_col0, #T_3ef0f_row0_col1, #T_3ef0f_row0_col2, #T_3ef0f_row0_col3 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_3ef0f">
#   <thead>
#     <tr>
#       <th id="T_3ef0f_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_3ef0f_level0_col1" class="col_heading level0 col1" >mean_train_score</th>
#       <th id="T_3ef0f_level0_col2" class="col_heading level0 col2" >mean_val_score</th>
#       <th id="T_3ef0f_level0_col3" class="col_heading level0 col3" >rank_val_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_3ef0f_row0_col0" class="data row0 col0" >{'n_neighbors': 60, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_3ef0f_row0_col2" class="data row0 col2" >0.979699</td>
#       <td id="T_3ef0f_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row1_col0" class="data row1 col0" >{'n_neighbors': 55, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_3ef0f_row1_col2" class="data row1 col2" >0.979383</td>
#       <td id="T_3ef0f_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row2_col0" class="data row2 col0" >{'n_neighbors': 50, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_3ef0f_row2_col2" class="data row2 col2" >0.979383</td>
#       <td id="T_3ef0f_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row3_col0" class="data row3 col0" >{'n_neighbors': 30, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_3ef0f_row3_col2" class="data row3 col2" >0.979065</td>
#       <td id="T_3ef0f_row3_col3" class="data row3 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row4_col0" class="data row4 col0" >{'n_neighbors': 30, 'weights': 'uniform'}</td>
#       <td id="T_3ef0f_row4_col1" class="data row4 col1" >0.981922</td>
#       <td id="T_3ef0f_row4_col2" class="data row4 col2" >0.979064</td>
#       <td id="T_3ef0f_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row5_col0" class="data row5 col0" >{'n_neighbors': 50, 'weights': 'uniform'}</td>
#       <td id="T_3ef0f_row5_col1" class="data row5 col1" >0.980257</td>
#       <td id="T_3ef0f_row5_col2" class="data row5 col2" >0.978749</td>
#       <td id="T_3ef0f_row5_col3" class="data row5 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row6_col0" class="data row6 col0" >{'n_neighbors': 65, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_3ef0f_row6_col2" class="data row6 col2" >0.978431</td>
#       <td id="T_3ef0f_row6_col3" class="data row6 col3" >7</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row7_col0" class="data row7 col0" >{'n_neighbors': 60, 'weights': 'uniform'}</td>
#       <td id="T_3ef0f_row7_col1" class="data row7 col1" >0.979940</td>
#       <td id="T_3ef0f_row7_col2" class="data row7 col2" >0.977481</td>
#       <td id="T_3ef0f_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row8_col0" class="data row8 col0" >{'n_neighbors': 70, 'weights': 'uniform'}</td>
#       <td id="T_3ef0f_row8_col1" class="data row8 col1" >0.977958</td>
#       <td id="T_3ef0f_row8_col2" class="data row8 col2" >0.976528</td>
#       <td id="T_3ef0f_row8_col3" class="data row8 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row9_col0" class="data row9 col0" >{'n_neighbors': 70, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row9_col1" class="data row9 col1" >1.000000</td>
#       <td id="T_3ef0f_row9_col2" class="data row9 col2" >0.976211</td>
#       <td id="T_3ef0f_row9_col3" class="data row9 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row10_col0" class="data row10 col0" >{'n_neighbors': 85, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_3ef0f_row10_col2" class="data row10 col2" >0.975894</td>
#       <td id="T_3ef0f_row10_col3" class="data row10 col3" >11</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row11_col0" class="data row11 col0" >{'n_neighbors': 65, 'weights': 'uniform'}</td>
#       <td id="T_3ef0f_row11_col1" class="data row11 col1" >0.977244</td>
#       <td id="T_3ef0f_row11_col2" class="data row11 col2" >0.975577</td>
#       <td id="T_3ef0f_row11_col3" class="data row11 col3" >12</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row12_col0" class="data row12 col0" >{'n_neighbors': 75, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_3ef0f_row12_col2" class="data row12 col2" >0.975577</td>
#       <td id="T_3ef0f_row12_col3" class="data row12 col3" >12</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row13_col0" class="data row13 col0" >{'n_neighbors': 55, 'weights': 'uniform'}</td>
#       <td id="T_3ef0f_row13_col1" class="data row13 col1" >0.978592</td>
#       <td id="T_3ef0f_row13_col2" class="data row13 col2" >0.975262</td>
#       <td id="T_3ef0f_row13_col3" class="data row13 col3" >14</td>
#     </tr>
#     <tr>
#       <td id="T_3ef0f_row14_col0" class="data row14 col0" >{'n_neighbors': 80, 'weights': 'distance'}</td>
#       <td id="T_3ef0f_row14_col1" class="data row14 col1" >1.000000</td>
#       <td id="T_3ef0f_row14_col2" class="data row14 col2" >0.974626</td>
#       <td id="T_3ef0f_row14_col3" class="data row14 col3" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_learning_curve(knn_grid.best_estimator_, X, y)

plt.savefig('tex/img/classification/knn_lc.png')

# %% [markdown]
# ### Evaluation on the test set

# %%
y_pred = knn_grid.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9809885931558935

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       1.00      0.97      0.99       312
#          low       0.99      0.96      0.98       232
#       medium       0.97      0.99      0.98       508
#
#     accuracy                           0.98      1052
#    macro avg       0.99      0.98      0.98      1052
# weighted avg       0.98      0.98      0.98      1052

# %%
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['high', 'medium', 'low']), 
                         columns=['high', 'medium', 'low'], index=['high', 'medium', 'low'])
sns.heatmap(confusion, annot=True, fmt='g', cmap='YlGnBu');

plt.savefig('tex/img/classification/knn_confusion.png')

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
pipeline = Pipeline([('scaler', StandardScaler()), 
                     ('estimator', RandomForestClassifier())])

tuned_parameters = {'estimator__n_estimators': (10, 100, 1000, 1500, 2000), 
                    'estimator__bootstrap': (True, False), 
                    'estimator__max_depth': (10, 30, 60, 100), 
                    'estimator__min_samples_split': (2, 5, 10), 
                    'estimator__min_samples_leaf': (1, 2, 4), 
                    'estimator__max_features': (1, 'auto', 5)}

rf_grid = GridSearchCV(pipeline, 
                       param_grid=tuned_parameters, 
                       scoring='accuracy', 
                       cv=5,  # 5 fold cross validation
                       n_jobs=-1,  # use all processors 
                       refit=True,  # refit the best model on the full development set 
                       return_train_score=True, 
                       verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 1080 candidates, totalling 5400 fits
# C:\Users\akila\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\ensemble\_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
print_pretty_cv_results(rf_grid)
# Out:
# C:\Users\akila\AppData\Local\Temp\ipykernel_13376\3005877394.py:63: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()
# <style type="text/css">
# #T_d5951_row0_col0, #T_d5951_row0_col1, #T_d5951_row0_col2, #T_d5951_row0_col3 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_d5951">
#   <thead>
#     <tr>
#       <th id="T_d5951_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_d5951_level0_col1" class="col_heading level0 col1" >mean_train_score</th>
#       <th id="T_d5951_level0_col2" class="col_heading level0 col2" >mean_val_score</th>
#       <th id="T_d5951_level0_col3" class="col_heading level0 col3" >rank_val_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_d5951_row0_col0" class="data row0 col0" >{'bootstrap': True, 'max_depth': 60, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}</td>
#       <td id="T_d5951_row0_col1" class="data row0 col1" >1.000000</td>
#       <td id="T_d5951_row0_col2" class="data row0 col2" >0.969868</td>
#       <td id="T_d5951_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row1_col0" class="data row1 col0" >{'bootstrap': True, 'max_depth': 60, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 2000}</td>
#       <td id="T_d5951_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_d5951_row1_col2" class="data row1 col2" >0.969236</td>
#       <td id="T_d5951_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row2_col0" class="data row2 col0" >{'bootstrap': True, 'max_depth': 60, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1500}</td>
#       <td id="T_d5951_row2_col1" class="data row2 col1" >1.000000</td>
#       <td id="T_d5951_row2_col2" class="data row2 col2" >0.969236</td>
#       <td id="T_d5951_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row3_col0" class="data row3 col0" >{'bootstrap': True, 'max_depth': 60, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_d5951_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_d5951_row3_col2" class="data row3 col2" >0.969236</td>
#       <td id="T_d5951_row3_col3" class="data row3 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row4_col0" class="data row4 col0" >{'bootstrap': True, 'max_depth': 100, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 2000}</td>
#       <td id="T_d5951_row4_col1" class="data row4 col1" >1.000000</td>
#       <td id="T_d5951_row4_col2" class="data row4 col2" >0.969235</td>
#       <td id="T_d5951_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row5_col0" class="data row5 col0" >{'bootstrap': True, 'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 2000}</td>
#       <td id="T_d5951_row5_col1" class="data row5 col1" >1.000000</td>
#       <td id="T_d5951_row5_col2" class="data row5 col2" >0.968919</td>
#       <td id="T_d5951_row5_col3" class="data row5 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row6_col0" class="data row6 col0" >{'bootstrap': True, 'max_depth': 100, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}</td>
#       <td id="T_d5951_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_d5951_row6_col2" class="data row6 col2" >0.968919</td>
#       <td id="T_d5951_row6_col3" class="data row6 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row7_col0" class="data row7 col0" >{'bootstrap': True, 'max_depth': 100, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}</td>
#       <td id="T_d5951_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_d5951_row7_col2" class="data row7 col2" >0.968918</td>
#       <td id="T_d5951_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row8_col0" class="data row8 col0" >{'bootstrap': True, 'max_depth': 100, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 1500}</td>
#       <td id="T_d5951_row8_col1" class="data row8 col1" >1.000000</td>
#       <td id="T_d5951_row8_col2" class="data row8 col2" >0.968601</td>
#       <td id="T_d5951_row8_col3" class="data row8 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row9_col0" class="data row9 col0" >{'bootstrap': True, 'max_depth': 60, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 1000}</td>
#       <td id="T_d5951_row9_col1" class="data row9 col1" >1.000000</td>
#       <td id="T_d5951_row9_col2" class="data row9 col2" >0.968601</td>
#       <td id="T_d5951_row9_col3" class="data row9 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row10_col0" class="data row10 col0" >{'bootstrap': True, 'max_depth': 100, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_d5951_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_d5951_row10_col2" class="data row10 col2" >0.968601</td>
#       <td id="T_d5951_row10_col3" class="data row10 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row11_col0" class="data row11 col0" >{'bootstrap': True, 'max_depth': 30, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100}</td>
#       <td id="T_d5951_row11_col1" class="data row11 col1" >1.000000</td>
#       <td id="T_d5951_row11_col2" class="data row11 col2" >0.968600</td>
#       <td id="T_d5951_row11_col3" class="data row11 col3" >12</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row12_col0" class="data row12 col0" >{'bootstrap': True, 'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 2000}</td>
#       <td id="T_d5951_row12_col1" class="data row12 col1" >1.000000</td>
#       <td id="T_d5951_row12_col2" class="data row12 col2" >0.968285</td>
#       <td id="T_d5951_row12_col3" class="data row12 col3" >13</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row13_col0" class="data row13 col0" >{'bootstrap': True, 'max_depth': 100, 'max_features': 1, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 2000}</td>
#       <td id="T_d5951_row13_col1" class="data row13 col1" >1.000000</td>
#       <td id="T_d5951_row13_col2" class="data row13 col2" >0.968285</td>
#       <td id="T_d5951_row13_col3" class="data row13 col3" >13</td>
#     </tr>
#     <tr>
#       <td id="T_d5951_row14_col0" class="data row14 col0" >{'bootstrap': True, 'max_depth': 30, 'max_features': 'auto', 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 100}</td>
#       <td id="T_d5951_row14_col1" class="data row14 col1" >1.000000</td>
#       <td id="T_d5951_row14_col2" class="data row14 col2" >0.968284</td>
#       <td id="T_d5951_row14_col3" class="data row14 col3" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_learning_curve(rf_grid.best_estimator_, X, y)

plt.savefig('tex/img/classification/rf_lc.png')

# %% [markdown]
# ### Evaluation on the test set

# %%
y_pred = rf_grid.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.964828897338403

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.97      0.96      0.97       312
#          low       0.98      0.94      0.96       232
#       medium       0.95      0.98      0.96       508
#
#     accuracy                           0.96      1052
#    macro avg       0.97      0.96      0.96      1052
# weighted avg       0.97      0.96      0.96      1052

# %%
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['high', 'medium', 'low']), 
                         columns=['high', 'medium', 'low'], index=['high', 'medium', 'low'])
sns.heatmap(confusion, annot=True, fmt='g', cmap='YlGnBu');

plt.savefig('tex/img/classification/rf_confusion.png')

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier, export_graphviz

# %%
pipeline = Pipeline([('scaler', StandardScaler()), 
                     ('estimator', DecisionTreeClassifier())])

tuned_parameters = {'estimator__splitter': ('best', 'random'),
                    'estimator__max_depth': (10, 30, 60, 100, 200, 500),
                    'estimator__min_samples_split': (2, 5, 10, 15, 20, 30),
                    'estimator__min_samples_leaf': (1, 2, 4, 7, 10, 15),
                    'estimator__max_features': (1, 'auto', 5, 7, 10, 15),
                    'estimator__criterion': ('gini', 'entropy')}

dt_grid = GridSearchCV(pipeline,
                       param_grid=tuned_parameters,
                       scoring='accuracy',
                       cv=5,  # 5 fold cross validation
                       n_jobs=-1,  # use all processors
                       refit=True,  # refit the best model on the full development set
                       return_train_score=True,
                       verbose=True).fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 5184 candidates, totalling 25920 fits

# %%
print_pretty_cv_results(dt_grid)
# Out:
# C:\Users\akila\AppData\Local\Temp\ipykernel_13376\3005877394.py:63: FutureWarning: this method is deprecated in favour of `Styler.hide(axis="index")`
#   return df.head(15).style.apply(highlight_equal, value=1, column=['rank_val_score'], axis=1).hide_index()
# <style type="text/css">
# #T_9cde3_row0_col0, #T_9cde3_row0_col1, #T_9cde3_row0_col2, #T_9cde3_row0_col3 {
#   background-color: lightyellow;
# }
# </style>
# <table id="T_9cde3">
#   <thead>
#     <tr>
#       <th id="T_9cde3_level0_col0" class="col_heading level0 col0" >params</th>
#       <th id="T_9cde3_level0_col1" class="col_heading level0 col1" >mean_train_score</th>
#       <th id="T_9cde3_level0_col2" class="col_heading level0 col2" >mean_val_score</th>
#       <th id="T_9cde3_level0_col3" class="col_heading level0 col3" >rank_val_score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_9cde3_row0_col0" class="data row0 col0" >{'criterion': 'entropy', 'max_depth': 500, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row0_col1" class="data row0 col1" >0.994767</td>
#       <td id="T_9cde3_row0_col2" class="data row0 col2" >0.950203</td>
#       <td id="T_9cde3_row0_col3" class="data row0 col3" >1</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row1_col0" class="data row1 col0" >{'criterion': 'entropy', 'max_depth': 60, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row1_col1" class="data row1 col1" >0.996591</td>
#       <td id="T_9cde3_row1_col2" class="data row1 col2" >0.949572</td>
#       <td id="T_9cde3_row1_col3" class="data row1 col3" >2</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row2_col0" class="data row2 col0" >{'criterion': 'entropy', 'max_depth': 10, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row2_col1" class="data row2 col1" >0.996115</td>
#       <td id="T_9cde3_row2_col2" class="data row2 col2" >0.949571</td>
#       <td id="T_9cde3_row2_col3" class="data row2 col3" >3</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row3_col0" class="data row3 col0" >{'criterion': 'entropy', 'max_depth': 30, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row3_col1" class="data row3 col1" >1.000000</td>
#       <td id="T_9cde3_row3_col2" class="data row3 col2" >0.949571</td>
#       <td id="T_9cde3_row3_col3" class="data row3 col3" >4</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row4_col0" class="data row4 col0" >{'criterion': 'entropy', 'max_depth': 100, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row4_col1" class="data row4 col1" >0.996670</td>
#       <td id="T_9cde3_row4_col2" class="data row4 col2" >0.949254</td>
#       <td id="T_9cde3_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row5_col0" class="data row5 col0" >{'criterion': 'entropy', 'max_depth': 200, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row5_col1" class="data row5 col1" >0.996591</td>
#       <td id="T_9cde3_row5_col2" class="data row5 col2" >0.948938</td>
#       <td id="T_9cde3_row5_col3" class="data row5 col3" >6</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row6_col0" class="data row6 col0" >{'criterion': 'entropy', 'max_depth': 10, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row6_col1" class="data row6 col1" >0.994450</td>
#       <td id="T_9cde3_row6_col2" class="data row6 col2" >0.948618</td>
#       <td id="T_9cde3_row6_col3" class="data row6 col3" >7</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row7_col0" class="data row7 col0" >{'criterion': 'entropy', 'max_depth': 100, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row7_col1" class="data row7 col1" >0.994846</td>
#       <td id="T_9cde3_row7_col2" class="data row7 col2" >0.948616</td>
#       <td id="T_9cde3_row7_col3" class="data row7 col3" >8</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row8_col0" class="data row8 col0" >{'criterion': 'entropy', 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row8_col1" class="data row8 col1" >0.996274</td>
#       <td id="T_9cde3_row8_col2" class="data row8 col2" >0.948305</td>
#       <td id="T_9cde3_row8_col3" class="data row8 col3" >9</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row9_col0" class="data row9 col0" >{'criterion': 'entropy', 'max_depth': 10, 'max_features': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row9_col1" class="data row9 col1" >0.999445</td>
#       <td id="T_9cde3_row9_col2" class="data row9 col2" >0.948304</td>
#       <td id="T_9cde3_row9_col3" class="data row9 col3" >10</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row10_col0" class="data row10 col0" >{'criterion': 'entropy', 'max_depth': 30, 'max_features': 15, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row10_col1" class="data row10 col1" >1.000000</td>
#       <td id="T_9cde3_row10_col2" class="data row10 col2" >0.948303</td>
#       <td id="T_9cde3_row10_col3" class="data row10 col3" >11</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row11_col0" class="data row11 col0" >{'criterion': 'entropy', 'max_depth': 500, 'max_features': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row11_col1" class="data row11 col1" >1.000000</td>
#       <td id="T_9cde3_row11_col2" class="data row11 col2" >0.948303</td>
#       <td id="T_9cde3_row11_col3" class="data row11 col3" >11</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row12_col0" class="data row12 col0" >{'criterion': 'entropy', 'max_depth': 100, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row12_col1" class="data row12 col1" >0.996591</td>
#       <td id="T_9cde3_row12_col2" class="data row12 col2" >0.948303</td>
#       <td id="T_9cde3_row12_col3" class="data row12 col3" >11</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row13_col0" class="data row13 col0" >{'criterion': 'entropy', 'max_depth': 100, 'max_features': 7, 'min_samples_leaf': 1, 'min_samples_split': 2, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row13_col1" class="data row13 col1" >1.000000</td>
#       <td id="T_9cde3_row13_col2" class="data row13 col2" >0.948302</td>
#       <td id="T_9cde3_row13_col3" class="data row13 col3" >14</td>
#     </tr>
#     <tr>
#       <td id="T_9cde3_row14_col0" class="data row14 col0" >{'criterion': 'entropy', 'max_depth': 200, 'max_features': 5, 'min_samples_leaf': 2, 'min_samples_split': 5, 'splitter': 'best'}</td>
#       <td id="T_9cde3_row14_col1" class="data row14 col1" >0.991595</td>
#       <td id="T_9cde3_row14_col2" class="data row14 col2" >0.948301</td>
#       <td id="T_9cde3_row14_col3" class="data row14 col3" >15</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_learning_curve(dt_grid.best_estimator_, X, y)

plt.savefig('tex/img/classification/dt_lc.png')

# %% [markdown]
# ### Evaluation on the test set

# %%
y_pred = dt_grid.best_estimator_.predict(X_test)
accuracy_score(y_pred, y_test)
# Out:
# 0.9534220532319392

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#         high       0.98      0.96      0.97       312
#          low       0.95      0.91      0.93       232
#       medium       0.94      0.97      0.95       508
#
#     accuracy                           0.95      1052
#    macro avg       0.96      0.95      0.95      1052
# weighted avg       0.95      0.95      0.95      1052

# %%
confusion = pd.DataFrame(confusion_matrix(y_test, y_pred, labels=['high', 'medium', 'low']), 
                         columns=['high', 'medium', 'low'], index=['high', 'medium', 'low'])
sns.heatmap(confusion, annot=True, fmt='g', cmap='YlGnBu');

plt.savefig('tex/img/classification/dt_confusion.png')

# %%
import pydotplus
from IPython.display import Image 

dot_data = export_graphviz(dt_grid.best_estimator_['estimator'], 
                           feature_names=df_customer_profile.columns[:-1], 
                           class_names=df_customer_profile['cluster'].unique(), 
                           out_file=None, 
                           filled=True, 
                           rounded=True) 
pydot_graph = pydotplus.graph_from_dot_data(dot_data)
pydot_graph.write_png('tex/img/classification/decision_tree.png')
Image(pydot_graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# Cell In[49], line 11
#       4 dot_data = export_graphviz(dt_grid.best_estimator_['estimator'],
#       5                            feature_names=df_customer_profile.columns[:-1],
#       6                            class_names=df_customer_profile['cluster'].unique(),
#       7                            out_file=None,
#       8                            filled=True,
#       9                            rounded=True)
#      10 pydot_graph = pydotplus.graph_from_dot_data(dot_data)
# ---> 11 pydot_graph.write_png('tex/img/classification/decision_tree.png')
#      12 Image(pydot_graph.create_png())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pydotplus\graphviz.py:1810, in Dot.__init__.<locals>.<lambda>(path, f, prog)
#    1800     f.__doc__ = (
#    1801         '''Refer to the docstring accompanying the'''
#    1802         ''''create' method for more information.'''
#    1803     )
#    1805 for frmt in self.formats + ['raw']:
#    1806     self.__setattr__(
#    1807         'write_' + frmt,
#    1808         lambda path,
#    1809         f=frmt,
# -> 1810         prog=self.prog: self.write(path, format=f, prog=prog)
#    1811     )
#    1813     f = self.__dict__['write_' + frmt]
#    1814     f.__doc__ = (
#    1815         '''Refer to the docstring accompanying the'''
#    1816         ''''write' method for more information.'''
#    1817     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pydotplus\graphviz.py:1918, in Dot.write(self, path, prog, format)
#    1915         fobj.write(data)
#    1917     else:
# -> 1918         fobj.write(self.create(prog, format))
#    1919 finally:
#    1920     if close:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pydotplus\graphviz.py:1959, in Dot.create(self, prog, format)
#    1957     self.progs = find_graphviz()
#    1958     if self.progs is None:
# -> 1959         raise InvocationException(
#    1960             'GraphViz\'s executables not found')
#    1962 if prog not in self.progs:
#    1963     raise InvocationException(
#    1964         'GraphViz\'s executable "%s" not found' % prog)
#
# InvocationException: GraphViz's executables not found
